# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import pandas as pd
import numpy as np

# %%
url0 = 'https://www.senyak.am/vacharq'
apparts = []

# %%
url = url0
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find_all('div', attrs={'class':'listing-item'})

# %%
for row in results:
    app = {}
    try:
        app['id'] = row.find('h2', attrs={'class': 'h4'}).text
    except:
        app['id'] = row.find('h2', attrs={'class': 'h4'})
    try:
        app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'}).text
    except:
        app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'})
    try:
        app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'}).text.replace('\n',"")
    except:
        app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'})
    try:
        app['info'] = row.find('div', attrs={'class': 'listing-body'}).text
    except:
        app['info'] = row.find('div', attrs={'class': 'listing-body'})
    try:
        app['price'] = row.find('div', attrs={'class': 'listing-img-content'}).text.replace('\n',"")
    except:
        app['price'] = row.find('div', attrs={'class': 'listing-img-content'})

    apparts.append(app)

# %%
apparts
# Out:
# [{'id': ' Այգի  ',
#   'sqm': '30000 մ²խմելու և ոռոգման ջուր',
#   'address': '  Արագածոտնի մարզ, Արագածավան գյուղ ',
#   'info': 'Վաճառվում է պտղատու այգի /ծիրան/ 30000քմ ընդհանուր մակերեսով: Այգին հիմնվել է 2007թ. -ին առկա է 4800 պտղատու ծիրանի ծառ, ոռոգման ջուր, հակակարկտային կայան, այգին',
#   'price': '$350\xa0000 '},
#  {'id': ' Բնակարան նորմալ վիճակում ',
#   'sqm': '2 սեն.6/9 հարկ68 մ²',
#   'address': '  Երևան, Ավան, Ավան-Առինջի 1-ին միկրոշրջան ',
#   'info': 'Ավավն Առինջ 1-ին միկրո․, 2-3 սենյակ, 68 քմ, 9/6-րդ հարկ - գույք և տեխնիկա - եվրո պատուհան - ջեռուցում - գորգ մանրահատակ - չեխական սալիկ/մետլախ',
#   'price': '$75\xa0000 '},
#  {'id': ' Բնակարան կապիտալ վերանորոգված ',
#   'sqm': '2 սեն.14/14 հարկ52 մ²',
#   'address': '  Երևան, Արգիշտի փողոց, 11/3 ',
#   'info': 'Продается 2-комнатная квартира, 52 кв. М. С земельным участком, расположенным по улице Аргишти, район Глендейл Хиллз, на 14 этаже 14 этажного строящегося дома. Квартира',
# ...

# %%
for i in range(2, 66):
    url = f"{url0}?page={i}"

    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find_all('div', attrs={'class':'listing-item'})

    for row in results:
        app = {}
        try:
            app['id'] = row.find('h2', attrs={'class': 'h4'}).text
        except:
            app['id'] = row.find('h2', attrs={'class': 'h4'})
        try:
            app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'}).text
        except:
            app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'})
        try:
            app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'}).text.replace('\n',"")
        except:
            app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'})
        try:
            app['info'] = row.find('div', attrs={'class': 'listing-body'}).text
        except:
            app['info'] = row.find('div', attrs={'class': 'listing-body'})
        try:
            app['price'] = row.find('div', attrs={'class': 'listing-img-content'}).text.replace('\n',"")
        except:
            app['price'] = row.find('div', attrs={'class': 'listing-img-content'})

        apparts.append(app)

# %%
df = pd.DataFrame.from_records(apparts)

# %%
df
# Out:
#                                         id                            sqm  \
# 0                                   Այգի    30000 մ²խմելու և ոռոգման ջուր
# 1                Բնակարան նորմալ վիճակում             2 սեն.6/9 հարկ68 մ²
# 2           Բնակարան կապիտալ վերանորոգված           2 սեն.14/14 հարկ52 մ²
# 3          Սեփական տուն զրոյական վիճակում         5 սեն.130 մ²հող՝ 265 մ²
# 4      Շքեղ Առանձնատուն զրոյական վիճակում         6 սեն.230 մ²հող՝ 500 մ²
# ...                                    ...                            ...
# 1795             Ամառանոց նորմալ վիճակում        4 սեն.250 մ²հող՝ 1024 մ²
# 1796                            Ավտոտնակ                    մակերես 21 մ²
# 1797       Բնակարան կոսմետիկ վերանորոգված             3 սեն.1/9 հարկ78 մ²
# 1798        Բնակարան կապիտալ վերանորոգված             1 սեն.5/5 հարկ37 մ²
# 1799                       Առևտրի տարածք                    մակերես 48 մ²
#
#                                             address  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1800 non-null   object
#  1   sqm      1800 non-null   object
#  2   address  1756 non-null   object
#  3   info     1800 non-null   object
#  4   price    1800 non-null   object
# dtypes: object(5)
# memory usage: 70.4+ KB

# %%
df['desc'] = df['sqm']

# %%
df['sqm'] = df['sqm'].astype(str)

# %%
df['rooms'] = df['sqm'].str[0]

# %%
df['floor'] = df['sqm'].str[6:11]

# %%
df['floor'] = df['floor'].str.replace('հ', '')

# %%
df['sqm'] = df['sqm'].str[-9:]

# %%
df.sqm = df.sqm.str.replace('կ', '')
df.sqm = df.sqm.str.replace('հ', '')
df.sqm = df.sqm.str.replace('ր', '')
df.sqm = df.sqm.str.replace('ղ', '')
df.sqm = df.sqm.str.replace('ս', '')
df.sqm = df.sqm.str.replace('ն', '')
df.sqm = df.sqm.str.replace('ե', '')
df.sqm = df.sqm.str.replace('.', '')
df.sqm = df.sqm.str.replace('ղ', '')
df.sqm = df.sqm.str.replace('ա', '')
df.sqm = df.sqm.str.replace('ո', '')
df.sqm = df.sqm.str.replace('խ', '')
df.sqm = df.sqm.str.replace('՝', '')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10800/312124816.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.sqm = df.sqm.str.replace('.', '')

# %%
df
# Out:
#                                         id       sqm  \
# 0                                   Այգի       գմ ջւ
# 1                Բնակարան նորմալ վիճակում      68 մ²
# 2           Բնակարան կապիտալ վերանորոգված      52 մ²
# 3          Սեփական տուն զրոյական վիճակում     265 մ²
# 4      Շքեղ Առանձնատուն զրոյական վիճակում     500 մ²
# ...                                    ...       ...
# 1795             Ամառանոց նորմալ վիճակում    1024 մ²
# 1796                            Ավտոտնակ       21 մ²
# 1797       Բնակարան կոսմետիկ վերանորոգված      78 մ²
# 1798        Բնակարան կապիտալ վերանորոգված      37 մ²
# 1799                       Առևտրի տարածք       48 մ²
#
#                                             address  \
# 0                Արագածոտնի մարզ, Արագածավան գյուղ
# 1         Երևան, Ավան, Ավան-Առինջի 1-ին միկրոշրջան
# 2                       Երևան, Արգիշտի փողոց, 11/3
# 3                      Երևան, Հաղթանակի 1-ին փողոց
# 4       Երևան, Աջափնյակ, Նազարբեկյան թաղամաս, 57/3
# ...

# %%
df.to_excel('C:\AUA\Capstone\project\data\senyak_data.xlsx')

# %%
# made changes in excel

# %%
url0 = 'https://www.senyak.am/vardzakalutyun'
apparts = []

# %%
url = url0
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find_all('div', attrs={'class':'listing-item'})

# %%
for row in results:
    app = {}
    try:
        app['id'] = row.find('h2', attrs={'class': 'h4'}).text
    except:
        app['id'] = row.find('h2', attrs={'class': 'h4'})
    try:
        app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'}).text
    except:
        app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'})
    try:
        app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'}).text.replace('\n',"")
    except:
        app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'})
    try:
        app['info'] = row.find('div', attrs={'class': 'listing-body'}).text
    except:
        app['info'] = row.find('div', attrs={'class': 'listing-body'})
    try:
        app['price'] = row.find('div', attrs={'class': 'listing-img-content'}).text.replace('\n',"")
    except:
        app['price'] = row.find('div', attrs={'class': 'listing-img-content'})

    apparts.append(app)

# %%
for i in range(2, 52):
    url = f"{url0}?page={i}"

    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    results = soup.find_all('div', attrs={'class':'listing-item'})

    for row in results:
        app = {}
        try:
            app['id'] = row.find('h2', attrs={'class': 'h4'}).text
        except:
            app['id'] = row.find('h2', attrs={'class': 'h4'})
        try:
            app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'}).text
        except:
            app['sqm'] = row.find("ul", attrs={'class':'listing-details text-nowrap'})
        try:
            app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'}).text.replace('\n',"")
        except:
            app['address'] = row.find('a', attrs={'class':'listing-address popup-with-zoom-anim'})
        try:
            app['info'] = row.find('div', attrs={'class': 'listing-body'}).text
        except:
            app['info'] = row.find('div', attrs={'class': 'listing-body'})
        try:
            app['price'] = row.find('div', attrs={'class': 'listing-img-content'}).text.replace('\n',"")
        except:
            app['price'] = row.find('div', attrs={'class': 'listing-img-content'})

        apparts.append(app)

# %%
df = pd.DataFrame.from_records(apparts)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1454 entries, 0 to 1453
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1454 non-null   object
#  1   sqm      1454 non-null   object
#  2   address  1418 non-null   object
#  3   info     1454 non-null   object
#  4   price    1454 non-null   object
# dtypes: object(5)
# memory usage: 56.9+ KB

# %%
df['desc'] = df['sqm']
df['sqm'] = df['sqm'].astype(str)
df['rooms'] = df['sqm'].str[0]
df['floor'] = df['sqm'].str[6:11]
df['floor'] = df['floor'].str.replace('հ', '')
df['sqm'] = df['sqm'].str[-9:]

# %%
df.sqm = df.sqm.str.replace('կ', '')
df.sqm = df.sqm.str.replace('հ', '')
df.sqm = df.sqm.str.replace('ր', '')
df.sqm = df.sqm.str.replace('ղ', '')
df.sqm = df.sqm.str.replace('ս', '')
df.sqm = df.sqm.str.replace('ն', '')
df.sqm = df.sqm.str.replace('ե', '')
df.sqm = df.sqm.str.replace('.', '')
df.sqm = df.sqm.str.replace('ղ', '')
df.sqm = df.sqm.str.replace('ա', '')
df.sqm = df.sqm.str.replace('ո', '')
df.sqm = df.sqm.str.replace('խ', '')
df.sqm = df.sqm.str.replace('՝', '')
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10800/2971978117.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.sqm = df.sqm.str.replace('.', '')

# %%
df
# Out:
#                                         id      sqm  \
# 0     ՇՏԱՊ  Բնակարան կապիտալ վերանորոգված     60 մ²
# 1      Սեփական տուն կոսմետիկ վերանորոգված     50 մ²
# 2           Բնակարան կապիտալ վերանորոգված     80 մ²
# 3          Բնակարան կոսմետիկ վերանորոգված     62 մ²
# 4      Բնակարան դիզայներական վերանորոգված     96 մ²
# ...                                    ...      ...
# 1449    Սեփական տուն կապիտալ վերանորոգված    400 մ²
# 1450  ՇՏԱՊ  Բնակարան կապիտալ վերանորոգված     60 մ²
# 1451             Բնակարան նորմալ վիճակում     65 մ²
# 1452   Բնակարան դիզայներական վերանորոգված     80 մ²
# 1453                     Օֆիսային տարածք     320 մ²
#
#                                  address  \
# 0       Երևան, Եզնիկ Կողբացու փողոց, 36
# 1                 Երևան, Ոսկանյան փողոց
# 2                   Երևան, Րաֆֆու փողոց
# 3          Երևան, Առնո Բաբաջանյան փողոց
# 4                Երևան, Քանաքեռ-Զեյթուն
# ...                                  ...
# 1449    Yerevan, Jrashen 1st Street, 40
# ...

# %%
df.to_excel('C:\AUA\Capstone\project\data\senyak_rents.xlsx')

# %%
# made changes in excel
